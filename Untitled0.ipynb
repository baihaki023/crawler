# %%
import tweepy
from textblob import TextBlob

# %%
consumer_key = 'O7H8dzerkUi1rfoc1Yf0n27GV'
consumer_secret = 'W8E6SPzBi76SWSAh1FhbpiFNx0TW8jLLv5FU26UAtcR3hGZ8V7'
access_token = '89192651-szUXRV8wGlgYL6E0OemwrG9GRgY0OvAI0mhMUpcq4'
access_token_secret = '0rM14tIfe1mCz7EboOtGRxhN6ep64UMrC8P4h48TDdzU9'

auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)

# %%
public_tweets = api.search (q=['ovo','gopay'] , count= 50)

# %%
all_polarity = 0
for tweet in public_tweets:
    print(tweet.text)
    
    analysis = TextBlob(tweet.text)
    an = analysis.translate(from_lang='id', to='en')
    print(an.sentiment)
    all_polarity += an.polarity
    
    print("")
# Out:
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# @Eunsobie App premium murah legal full garansi🔥
# 🌼 Netflix
# sharing 30k, private 120k
#
# 🌼 Spotify
# aktivasi 10k, perpa… https://t.co/dmIsK8O90p
# Sentiment(polarity=0.23750000000000002, subjectivity=0.45625)
#
# @nirma_np hadiirrr kak, tf langsung dpt akun
#
# ❗ NETFLIX FRESH BILLING❗
#
# ▪ SHARING 30K
# ▪ PRIVATE 120K
#
# 🍿ANTI HOLD, L… https://t.co/BCStiuPktE
# Sentiment(polarity=0.15, subjectivity=0.4375)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/PmpMeQNIGJ
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/HHoznfKB7K
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/MIxRg5B7FX
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/y2SzvaLT01
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/TuxIO9DDBs
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/lRfhnRZZPx
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/NX2iMA9grx
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/Zt6XPpxx3J
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/a4Y77EhBEV
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/WckdJfmeWh
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/guQNArNsUJ
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/LdFJpVOJDi
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/MfZMYbUXEJ
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/K4PoPnp5BB
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/NacVAZ3T35
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/uulm90uqhW
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/XI4kj6C2uH
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# RT @jamaisvtae_: [GIVEAWAY]
#
# Karna BTS masuk lagi ke # 1 BB Hot100 sama #1 BB Global 200 dan BB Global Excl. US aku mau GA untuk 2 orang 💜💜…
# Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/18QHjRoRLR
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/21mUtqGspx
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/wioz9X11fY
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# √ada harga ada kualitas√
# 🎬NETFLIX
# •35K SHARING
# •125K PRIVATE (ppj +5k)
#
# ✅ultra HD 4k
# 💯legal, aman, full garansi
# 📌t… https://t.co/3Xv7Le3p8U
# Sentiment(polarity=0.2833333333333333, subjectivity=0.47500000000000003)
#
# hi! aku jual netflix antihold, fresh bill ✨🎪
#
# ✅ 3O,OOO / BULAN ✅
#
# ❗PAKET NETFLIX + SPOTIFY 38,OOO only❗
#
# ✓ 4K UHD,… https://t.co/hIftBfKj9o
# Sentiment(polarity=0.3, subjectivity=0.5)
#
# @ekaaaasn hadiirrr kak, tf langsung proses
#
# SPOTIFY
# aktivasi
# 1 bulan 10k
# 2 bulan 18k
# 3 bulan 27k
# 6 bulan 38k
# perpan… https://t.co/X5PvJHMjXL
# Sentiment(polarity=0.375, subjectivity=0.375)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# WTS INACT Y14
#
# 5K sisa 1 yuk take
#
# 💯V email only (yahoo)/v all +1k
# 💯Dpt email+pw
# 💯F-ing+dm bersih
# 💯Bebas sb
# 💯Bisa t… https://t.co/1lKOTvFLYQ
# Sentiment(polarity=0.2555555555555556, subjectivity=0.8333333333333334)
#
# @sharen05 hadiirrr kak, tf langsung proses
#
# SPOTIFY
# aktivasi
# 1 bulan 10k
# 2 bulan 18k
# 3 bulan 27k
# 6 bulan 38k
# perpan… https://t.co/0nAp6vgOp1
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @purpleeKYUN: ⚠️⚠️ ᵐᶦⁿᶦ GIVEAWAY 💜⚠️
# OVO/GOPAY/PULSA buat 2 biji orang @ idr 100k
#
# 🔥like♥️/RT🔁
# 🔥sebut provider
# 🔥mention 2 temen onlen ka…
# Sentiment(polarity=1.0, subjectivity=1.0)
#
# RT @Matcha_Mint1210: GA (DANITY INA)
# “KANG DANIEL BIRTHDAY” 🥳
#
# 1 Wall Calendar Only
# 1 Slogan
# 5 Org saldo Dana/OVO/Gopay @20K
#
# S&amp;K:
# 🐶 RT +…
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# @mm34nismind hadiirrr kak, tf langsung proses
#
# SPOTIFY
# aktivasi
# 1 bulan 10k
# 2 bulan 18k
# 3 bulan 27k
# 6 bulan 38k
# per… https://t.co/Snfr1yZOt9
# Sentiment(polarity=0.1, subjectivity=0.4)
#
# RT @jumintensbybaru: Gass yukk📢📢📢
#
# 10K (shopeepay/ovo/gopay)
# RT dan follow aku
# Tag temen juga boleh
#
# End Dadakan
#
# 🎉 goodluck everyone 🎉
# Sentiment(polarity=0.25, subjectivity=0.5)
#
# READY 4 SLOT
#
# NETLIX ANTI ON HOLD‼
#
# ✨35k/bln (1 profile 1device)
#
# ✅ FULL GARANSI
# ✅ ANTI ONHOLD
# ✅ FULL 30 HARI, FRES… https://t.co/ALqBIaIpyL
# Sentiment(polarity=0.3, subjectivity=0.5333333333333333)
#
# RT @graciousgazelle: 1st DECEMBER GIVEAWAY!
# FAST GA 25k buat 1 orang yang RT + follow @grelle_GA
# bisa transfer/gopay/ovo
# good luck! 😚
# Sentiment(polarity=0.5375, subjectivity=0.6000000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# WTS KOSONGAN Y20 NOV
#
# 5K/acc
#
# ✨V all
# ✨Dpt pw+email
# ✨Minta code kalo L
# ✨Pf isat 28 des 20
# ✨Ada fitur lengkap story… https://t.co/jUdKFyceQj
# Sentiment(polarity=0.1, subjectivity=0.4)
#
# @rizkyarfian hadiirrr kak, tf langsung proses
#
# SPOTIFY
# aktivasi
# 1 bulan 10k
# 2 bulan 18k
# 3 bulan 27k
# 6 bulan 38k
# per… https://t.co/XDlkBeOOca
# Sentiment(polarity=0.1, subjectivity=0.4)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# RT @gryffinseok: GRYFFINSEOK’s GIVEAWAY
#
# Edisi Life Goes On entering 1st BB HOT 100 😍🧁sekaligus awal bulan biar berkah 🥰
#
# 💰Saldo 50 ♡
# 🌸 1…
# Sentiment(polarity=0.25, subjectivity=0.8500000000000001)
#
# @Eunsobie hadiirrr kak, tf langsung proses
#
# SPOTIFY
# aktivasi
# 1 bulan 10k
# 2 bulan 18k
# 3 bulan 27k
# 6 bulan 38k
# perpan… https://t.co/qeENhzmcwP
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @mm34nismind 🌈   SPOTIFY   🌈
# -
# Aktivasi
# ☁️ 8K / 1 bulan
# ☁️ 15K / 2 bulan
# ☁️ 20K / 3 bulan
# -
# Perpanjang
# ☁️ 10K / 1 b… https://t.co/g4HKC0vgDD
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @paradisejbm: ‼️GIVEAWAY‼️
# Karena lagi bahagia sama Daesang dan Comeback got7. Gue mau adain giveaway kecil2an.
#
# Akan ada 50k per-orang…
# Sentiment(polarity=0.30625, subjectivity=0.75)
#
# November kemaren ongkir gofood naik 3ribuan rata, grabfood masih normal, ookaylah desember ini banyakin top up ovo… https://t.co/bxz2gAiFFk
# Sentiment(polarity=0.125, subjectivity=0.4041666666666666)
#
# @Eunsobie 🌈   SPOTIFY   🌈
# -
# Aktivasi
# ☁️ 8K / 1 bulan
# ☁️ 15K / 2 bulan
# ☁️ 20K / 3 bulan
# -
# Perpanjang
# ☁️ 10K / 1 bula… https://t.co/B11UnsvtkX
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @jamaisvtae_: [GIVEAWAY]
#
# Karna BTS masuk lagi ke # 1 BB Hot100 sama #1 BB Global 200 dan BB Global Excl. US aku mau GA untuk 2 orang 💜💜…
# Sentiment(polarity=-0.25, subjectivity=0.3333333333333333)

# %%
#step 4 to check positive or negative sentiment from overasal tweetsif (all_polarity/100 > 0):
if (all_polarity/100 > 0):
    print(all_polarity/100)
    print("")
    print('Positive')
else :
    print(all_polarity/100)
    print("")
    print('Negative')
# Out:
# 0.11586805555555553
#
# Positive
